# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
waves = xr.open_dataset('../wekeo-hda/data/waves_spain_forecast.nc')

# %%
waves
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 24, time: 41, longitude: 111)
# Coordinates:
#   * latitude   (latitude) float64 42.5 42.58 42.67 42.75 ... 44.25 44.33 44.42
#   * time       (time) datetime64[ns] 2021-12-01 ... 2021-12-06
#   * longitude  (longitude) float64 -9.75 -9.667 -9.583 ... -0.75 -0.6667 -0.5833
# Data variables:
#     VHM0_SW1   (time, latitude, longitude) float32 ...
# Attributes: (12/31)
#     Conventions:                               CF-1.6
#     time_coverage_start:                       20211214-03:00:00
#     time_coverage_end:                         20211215-00:00:00
#     date_created:                              20211205-07:35:00
#     product_type:                              forecast
#     product:                                   GLOBAL_ANALYSIS_FORECAST_WAV_0...
#     ...                                        ...
#     FROM_ORIGINAL_FILE__geospatial_lat_step:   0.08333588
#     FROM_ORIGINAL_FILE__geospatial_lat_units:  degree
# ...

# %%
waves2 = xr.open_dataset('../data/med-hcmr-wav-an-fc-h_1638727456962.nc')

# %%
waves2.VHM0_WW[::10,:,:].plot(col='time',col_wrap=4,cmap='Spectral_r')
plt.show()
